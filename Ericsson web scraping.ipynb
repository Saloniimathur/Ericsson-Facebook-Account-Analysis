# %%
import csv
from datetime import datetime
import nltk
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from facebook_scraper import get_posts

# %%
# Set the page to scrape
page_name = "ericsson"

# %%
# Define the date range to scrape
since_date = datetime(2022, 1, 1)
until_date = datetime(2023, 4, 25)

# %%
# Define the CSV file to write the data to
csv_file = "ericsson_facebook.csv"

# %%
# Define the fieldnames for the CSV file
fieldnames = ["text", "date", "likes", "comments", "shares", "sentiment"]

# %%
# Open the CSV file for writing and write the header row
with open(csv_file, "w", encoding="utf-8", newline="") as f:
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    writer.writeheader()

    # Loop over the posts on the page within the date range
    for post in get_posts(page_name, pages=50, extra_info=True, timeout=30):
        if post["time"] < since_date or post["time"] > until_date:
            continue

        # Analyze the sentiment of the post text using VaderSentiment
        analyzer = SentimentIntensityAnalyzer()
        sentiment = analyzer.polarity_scores(post["text"])["compound"]

        # Convert the sentiment score to a sentiment label
        if sentiment > 0.05:
            sentiment_label = "Positive"
        elif sentiment < -0.05:
            sentiment_label = "Negative"
        else:
            sentiment_label = "Neutral"

        # Write the post data and sentiment to the CSV file
        writer.writerow({
            "text": post["text"],
            "date": post["time"].strftime("%Y-%m-%d %H:%M:%S"),
            "likes": post["likes"],
            "comments": post["comments"],
            "shares": post["shares"],
            "sentiment": sentiment_label
        })
        
         # Print the post details and sentiment
        print("Post: ", post["text"])
        print("Date: ", post["time"].strftime("%Y-%m-%d %H:%M:%S"))
        print("Likes: ", post["likes"])
        print("Comments: ", post["comments"])
        print("Shares: ", post["shares"])
        print("Sentiment: ", sentiment)
        print("\n")
# Out:
# C:\Users\Chinu\Python310\lib\site-packages\facebook_scraper\facebook_scraper.py:855: UserWarning: Facebook language detected as hi_IN - for best results, set to en_US
#   warnings.warn(
# Post:  Want to make a real difference this #EarthDay?
#
# Whether you plant a tree or clean up beaches, every action counts✅
#
# Explore more here 👉 http://m.eric.sn/HK9850NOTZQ
#
# #Sustainability #EarthDay
#
# ERICSSON.COM
# Sustainability and corporate responsibility
# Date:  2023-04-22 13:00:18
# Likes:  26
# Comments:  1
# Shares:  3
# Sentiment:  0.4588
#
#
# Post:  📢 Join Jenny Sandahl, our Sustainability Director for Design and Materials, to discuss "Exponential Supply Chains: Decarbonizing Global Supply Chains" on April 20th from 16:00 CEST.
#
# Discover how leadingअधिक companies are halving emissions through global supply chains and scaling best practices. Jenny will share cutting-edge initiatives and insights to drive sustainable supply chains and create lasting value for our planet 🌍
#
# Don't miss this opportunity to gain insights into creating sustainable supply chains.
#
# Register for the event here http://m.eric.sn/MonF50NKQXW
#
# #NetZero #ClimateAction #Sustainability #WeDontHaveTime
# Date:  2023-04-19 12:30:31
# Likes:  20
# Comments:  1
# Shares:  1
# Sentiment:  0.9657
#
#
# Post:  🌍 Our Head of Sustainability, Mats Pellbäck Scharp, will speak during #StockholmClimateWeek on April 20th at 16:00 CEST.
#
# Join us to learn about "Exponential Supply Chains: Decarbonizing Global Supply Chains"अधिक and how transforming the way we produce, transport, and consume goods and services to combat climate change 🌱
#
# This talk brings together leading companies that are halving emissions through their global supply chains and working to share and scale best practices globally.
#
# Don't miss out on this opportunity to learn and make a difference!
# Register now here 👉 http://m.eric.sn/1h7550NKF90
#
# #NetZero #ClimateAction #Sustainability #WeDontHaveTime
# Date:  2023-04-18 20:31:14
# Likes:  38
# Comments:  2
# Shares:  1
# Sentiment:  0.8803
#
#
# Post:  🌍 Join us for an inspiring talk by Emelie Öhlander, Climate Action Program Manager at Ericsson, as she discusses "Negative emissions – Sweden’s next export industry" on April 19th at 17:30 CEST.
#
# Learn howअधिक Sweden has the potential to become a leading supplier of carbon dioxide removals, creating a global market for negative emissions and creating over 25,000 jobs and increasing GDB by 2.4 billion a year! 📈
#
# Join the conversation by registering here: http://m.eric.sn/2xHZ50NKCLz
#
# #ClimateAction #Sustainability #NetZero #WeDontHaveTime
# Date:  2023-04-18 12:30:24
# Likes:  30
# Comments:  2
# Shares:  1
# Sentiment:  0.3595
#
#
# Post:  We're proud to be part of #StockholmClimateWeek, where experts and leaders will gather to discuss and find solutions on how to achieve #NetZero and drive #ClimateAction 🌱
#
# With experts and leaders from aroundअधिक the world gathering to discuss and find solutions, this is an opportunity to learn how to create a more sustainable future.
#
# We believe that technology has a key role to play in achieving net-zero emissions and are excited to share our insights and solutions with you at the event 💚
#
# Join us and register for the event here: http://m.eric.sn/wwBL50NKCh0
#
# #Sustainability #WeDontHaveTime
#
# WEDONTHAVETIME.ORG
# Stockholm Climate Week – Apr 18, 2023–Apr 22, 2023
# Date:  2023-04-17 20:30:32
# Likes:  24
# Comments:  1
# Shares:  0
# Sentiment:  0.9702
#
#
# Post:  The rise of #Industry 4.0 has brought significant advancements in efficiency and customization ⚙.
# However, it has also raised the question of what these advancements mean for society.
#
# In our new article 📃, weअधिक explore:
#
# 👷‍♀️ How machines and humans can work collaboratively.
#
# 💡 How cobots and exoskeletons can change the #Manufacturing landscape.
#
# 🤖The crucial role of communication and connectivity in the factory of the future.
#
# Are you curious about what the future of manufacturing will look like? 🤔
# Share your thoughts in the comments and know more by reading the article! #SmartFactory
#
# http://m.eric.sn/lIzC50NHRHj
# Date:  2023-04-13 13:47:48
# Likes:  23
# Comments:  1
# Shares:  0
# Sentiment:  0.8622
#
#
# Post:  As we celebrate World Health Day, let's not forget the importance of technology in promoting better health 💪
#
# Imagine a hospital that provides 5G-connected devices to patients that need to be tracked andअधिक monitored 24x7.
#
# From remote consultations🖥 to real-time monitoring🩺, 5G can empower patients and healthcare providers alike!
#
# Technology, when paired with human expertise, has the power to elevate healthcare services and even save lives.
#
# #WorldHealthDay #5G
# Date:  2023-04-07 12:31:08
# Likes:  37
# Comments:  2
# Shares:  0
# Sentiment:  0.9032
#
#
# Post:  Ericsson continues to push the boundaries of innovation! 🎉
#
# We are proud to announce that the latest EPO report has named us one of the top 5️⃣ patent applicants in 2022.
#
# This is a testament to our unwavering commitment to driving innovation and staying ahead of the curve.
#
# Innovation in digital communication fueled Ericsson's patent growth as weअधिक continue to lead the way in these fields. Our relentless pursuit of excellence has resulted in us being among the top 5 patent applicants at EPO for the 4th time since 2017 📈
#
# We are excited to be at the forefront of cutting-edge technology and are dedicated to creating solutions that improve people's lives. Join us on this journey toward a more connected future.
#
# Check out the link below to read the full EPO report 👇
#
# http://m.eric.sn/h3EC50NB8YG
# Date:  2023-04-06 12:30:20
# Likes:  190
# Comments:  5
# Shares:  0
# Sentiment:  0.9886
#
#
# Post:  The future of gaming is here, and it's all about network connectivity which is at the heart of gaming! 🎮
#
# Gamification is indeed the future, but it comes with its own challenges 📍. As we advance toward 2030,अधिक there will be greater demand for high-quality and secured connectivity.
#
# Want to know more about what the future holds? 👀
#
# Sound interesting? Find out more here: http://m.eric.sn/rNqq50Nv7tH
#
# #CloudGaming #Gamification #ImaginePossible
# Date:  2023-03-30 12:45:10
# Likes:  46
# Comments:  5
# Shares:  2
# Sentiment:  0.9294
#
#
# Post:  #DYK: 8️⃣ in 🔟 of urban early digital adopters believe personalized weather warning systems will be used by consumers in the 2030s?
#
# 🌧 We have the facts + figures in our 🆕 10 Hot Consumer Trends Report!
#
# अधिक Download the full report to learn why consumers believe #AI services will become critical during increasingly unpredictable and unstable weather ➡️ http://m.eric.sn/fn7A50NuAXI
#
# #ImaginePossible
# Date:  2023-03-29 15:30:33
# Likes:  25
# Comments:  1
# Shares:  0
# Sentiment:  -0.7574
#
#
# Post:  Do you have any tips to share on saving water?
# #WorldWaterDay 💧
#
# Water is a finite and essential resource for all life on Earth, so conscious water use and management is a key shared responsibility globally 🌎
#
# अधिक At Ericsson, we are committed to helping solve this challenge by using our technology to help create a more sustainable future.
#
# #Water #Sustainability #Technology
#
# ERICSSON.COM
# What is Smart Water?
# Date:  2023-03-22 16:30:20
# Likes:  19
# Comments:  5
# Shares:  0
# Sentiment:  0.9419
#
#
# Post:  We are committed to safeguarding our employees, customers, and partners as we believe in providing a safe and healthy work environment for all, encompassing physical, emotional, and social well-being.
#
# Thisअधिक World Sleep Day😴, make sure to:
#
# 📍Have a sleep-friendly space.
# 📍Follow regular bedtime and wake-up time.
# 📍Follow stretching and stress relief exercise regime.
#
# Make sure to get a restful sleep!
#
# #EricssonCare #SleepIsEssential#WorldSleepDay
# Date:  2023-03-19 15:30:47
# Likes:  28
# Comments:  1
# Shares:  0
# Sentiment:  0.9441
#
#
# Post:  📢 Attention game developers! Want to make your games accessible anywhere?
#
# Learn how companies like Vonage (part of Ericsson) are simplifying network developer interfaces to support the ecosystem and drive innovation in cloud gaming 🚀
#
# #ImaginePossible #5GGaming #5G #CloudGaming
# Date:  2023-03-16 13:31:42
# Likes:  48
# Comments:  1
# Shares:  0
# Sentiment:  0.8122
#
#
# Post:  What does the future of money look like to you? 🤔
#
# We believe it's a world of:
#
# ✔seamless,
# ✔secure,
# ✔and inclusive financial transactions
# ✔powered by innovative technologies like biometrics and AI.
#
# In ourअधिक latest article 📰, we explore the trends and technologies that are shaping the future of money and what it will take to build a trusted digital ecosystem.
#
# Read on to discover more! 🚀
# http://m.eric.sn/wlNu50Nfrtv
#
# #FutureOfMoney #DigitalTransformation #Trust
# Date:  2023-03-15 14:31:49
# Likes:  33
# Comments:  1
# Shares:  0
# Sentiment:  0.9273
#
#
# Post:  Strict time schedules may soon be a thing of the past.⏰ In fact, 6️⃣8️⃣% of consumers believe the future of scheduling will revolve primarily around energy efficiency!⚡️
#
# #ClimateChange regulations may user inअधिक no-rush mobility, creating a paradigm shift with the potential to change everything in work, school, and everyday activities.
#
# Learn more in our 🆕 10 Hot Consumer Trends Report. Download it here ➡️ http://m.eric.sn/temI50Nfkrk
# Date:  2023-03-13 13:31:34
# Likes:  14
# Comments:  0
# Shares:  0
# Sentiment:  0.5707
#
#
# Post:  Ready to connect everything, everywhere, at any time?🔮 Ericsson's Radio Access Networks makes it possible!
#
# From Indoor, Macro #5G to #CloudRAN and many more, we're propelling the industry forward withअधिक best-in-class network performance and empowering service providers to unlock new use cases every day.✨
#
# Meet the powerful #connectivity solutions in the Ericsson 5G RAN portfolio here ➡️ http://m.eric.sn/4bot50N0MV6
# Date:  2023-03-10 19:40:20
# Likes:  38
# Comments:  0
# Shares:  0
# Sentiment:  0.8221
#
#
# Post:  As technology shapes our world, women’s perspectives are needed in the industry and the digital economy to create a more equal future.
# This International Women’s Day, we recognize everybody who strives forअधिक greater equality and women and girls who champion the advancement of transformative technology, helping to make digital available for all. #DigitALL 🌐
# At Ericsson, women are not only shaping our business and culture but also championing groundbreaking innovation: 2️⃣5️⃣ % of our 60,000+ patents were invented or co-invented by at least one woman. Driven by our commitment to gender equality, we aim to increase the representation of women to 3️⃣0️⃣ % in our total workforce by 2030 to drive a more 💡 gender-intelligent organization.
# #IWD #IWD2023
# Date:  2023-03-08 14:08:12
# Likes:  46
# Comments:  0
# Shares:  0
# Sentiment:  0.9571
#
#
# Post:  Ericsson celebrates world wildlife day! 🐾
#
# We contribute using our advanced solutions-based intelligent networks to conserve world wildlife, including:
#
# 🪂AI-enabled drones to preserve endangered wildlife
# 📶IoTअधिक solution to conserve forests and save wildlife
# 💫Solar-power sensors and wireless connectivity to capture data
#
# Let us join hands and pledge to conserve and preserve flora and fauna this #WorldWildlifeDay! 🍀
#
# #PartnershipInConservation #WorldWildlifeDay #IoT#5G
# Date:  2023-03-03 17:31:02
# Likes:  67
# Comments:  4
# Shares:  2
# Sentiment:  0.9431
#
#
# Post:  How can the latest technology advance society? Find out at #MWC23!
#
# Connected technologies, such as #DigitalTwins, IoT, and the metaverse have opened a wealth of possibilities. For example, the development ofअधिक Smart Mobility solutions that make cities more liveable, efficient, and sustainable.
#
# 👉 Learn more about this amazing evolution with Ericsson's Mischa Dohler and other leading experts on March 1, 16:00 CET at Industry City Stage, Hall 4.
#
# Follow #EricssonMWC for updates.
# Date:  2023-03-01 13:31:18
# Likes:  32
# Comments:  1
# Shares:  1
# Sentiment:  0.9413
#
#
# Post:  Unlock the potential of drones through the power of cellular networks at #MWC23!
#
# Hear Ericsson’s Kapil Mittal and technology experts explain how 5G expands the horizon of Advanced Air Mobility and all the newअधिक opportunities that are waiting to be turned into reality for aviation communication.
#
# 🔴 Join the event live on March 1, 14:45 CET at Industry City Stage, Hall 4 and follow #EricssonMWC for updates!
#
# #5G #Tech #Innovation #Connectivity #Drones
# Date:  2023-03-01 12:45:10
# Likes:  52
# Comments:  1
# Shares:  3
# Sentiment:  0.855
#
#
# Post:  What’s next for immersive experiences? Uncover it at #MWC23!
#
# Hear Ericsson’s Mischa Dohler and leading technology experts taking a deep dive into how #XR, #AI, and #5G are blurring the lines between ourअधिक physical and digital worlds.
#
# ➡️ Be there live on March 1, 13:15 CET at MWC Stage C, Hall 6 and follow #EricssonMWC for more updates!
# Date:  2023-02-28 23:32:04
# Likes:  23
# Comments:  0
# Shares:  0
# Sentiment:  0.0
#
#
# Post:  Unlock the full potential of artificial and virtual reality services with 5G Advanced at #MWC23!
#
# Listen to Ericsson's Dr Sibel Tombaz and other industry-leading experts as they take a closer look at the futureअधिक of new #5G wireless innovations.
#
# 📌 Be there live on March 1, 10:50 CET at Theatre 2, Hall 6 and follow #EricssonMWC for updates.
# Date:  2023-02-28 22:31:17
# Likes:  30
# Comments:  0
# Shares:  1
# Sentiment:  0.3164
#
#
# Post:  How to work with suppliers, third parties, and partners to build on diversity, equity, and inclusion in all messaging? Find out at #MWC23!
#
# Ericsson's Katherine Ainley and leading experts at the Diversity4Techअधिक Summit will unpack this for you and everything else you need to know about DE&I.
#
# 🔴 Hear it live on March 1, 10:00 CET, at MWC Stage C, Hall 6 and follow #EricssonMWC for updates!
# Date:  2023-02-28 22:00:25
# Likes:  28
# Comments:  0
# Shares:  0
# Sentiment:  0.508
#
#
# Post:  How will banking evolve with new innovations in #FinTech?
#
# At #MWC23, Ericsson’s Ville Sointu and technology experts dive into the power of partnerships that enable rapid design, development, and launch of newअधिक products in this exiting and evolving space.
#
# 👉 Be there live on Feb. 28, 10:45 CET at Industry City Stage, Hall 4 and follow #EricssonMWC for updates!
# Date:  2023-02-28 17:31:08
# Likes:  26
# Comments:  0
# Shares:  0
# Sentiment:  0.0
#
#
# Post:  Get ready to experience the future with 5G Advanced!
#
# Join Ericsson's Dr Sibel Tombaz and other industry-leading experts to discover endless possibilities, including immersive experiences in the metaverse.
#
# 📅अधिक Mark your calendar for February 28, 11:30 CET and be at MWC Stage B, Hall 6 to catch the discussion live!
#
# Don’t forget to follow #EricssonMWC to get the latest updates from Barcelona.
#
# #5G #Metaverse #Technology
# Date:  2023-02-28 14:30:42
# Likes:  29
# Comments:  0
# Shares:  0
# Sentiment:  0.658
#
#
# Post:  How are Digital Twins driving future network transformation? Hear it at #MWC23!
#
# Join Ericsson’s Ebru Kirac and leading technology experts in a discussion about the endless possibilities #DigitalTwins enable forअधिक designing, testing, optimizing, and provisioning.
#
# 📍 Be there live on February 28 | 11:30 CET, at MWC Stage A, Hall 6 and follow #EricssonMWC for updates!
# Date:  2023-02-28 13:30:45
# Likes:  34
# Comments:  0
# Shares:  0
# Sentiment:  0.6988
#
#
# Post:  Stay ahead of the game with 5G Advanced at #MWC23!
#
# Immersive experiences, high-precision location and timing, and opening the doors of the metaverse are just some of the features you can unlock with 5G and 5Gअधिक Advanced technologies.
#
# 📍 Explore more with Ericsson's Dr Sibel Tombaz and other industry-leading experts on February 28, 11:30 CET at MWC Stage B, Hall 6.
#
# Follow #EricssonMWC for updates.
#
# #5G #Metaverse #Technology
# Date:  2023-02-28 00:31:07
# Likes:  49
# Comments:  1
# Shares:  1
# Sentiment:  0.5093
#
#
# Post:  Have you heard of #DigitalTwins? Join us at #MWC23 and find out how this technology drives network transformation!
#
# Digital Twins are virtual replicas of physical systems and processes, revolutionizing the wayअधिक we approach problem-solving and decision making. Hear Ericsson's Ebru Kirac and other leading tech experts discussing how it plays a crucial role in the modelling, and fine-tuning of today’s telecom innovation.
#
# 👉 See it live on February 28 | 11:30 CET, at MWC Stage A, Hall 6 and follow #EricssonMWC for updates!
# Date:  2023-02-27 23:31:32
# Likes:  26
# Comments:  2
# Shares:  1
# Sentiment:  0.7494
#
#
# Post:  How does fintech empower innovation in banking? Explore it with us at #MWC23!
#
# Get a glimpse into the future of banking from Ericsson’s Ville Sointu and other leading experts at the Fintech Summit.
#
# ➡️ Join inअधिक live on February 28, 10:45 CET at Industry City Stage, Hall 4 and follow #EricssonMWC for updates!
#
# #FinTech #BlockChain #Technology
# Date:  2023-02-27 22:31:19
# Likes:  32
# Comments:  0
# Shares:  0
# Sentiment:  0.658
#
#
# Post:  Is the industry meeting its sustainability targets? Take a deep dive into this topic at #MWC23!
#
# Listen to Ericsson’s Freddie Södergren, alongside leading experts, as they uncover how 5G, AI, virtualization, andअधिक cloud technologies can help create a #NetZero future.
#
# 📍 Be there live on February 27, 14:45 CET at MWC Stage B, Hall 6 and follow #EricssonMWC for updates!
# Date:  2023-02-27 18:30:51
# Likes:  30
# Comments:  1
# Shares:  1
# Sentiment:  0.658
#
#
# Post:  Enter the open API marketplace at #MWC23 to experience innovation like never before.
#
# Hear our CTO, Erik Ekudden, Savinay Berry, and other great industry leaders discuss the unprecedented opportunities inअधिक application development and market value creation at the “Opening up the power of the network” session.
#
# ▶️ Join live on February 27, 13:15 CET | MWC Stage A, Hall 6 and follow #EricssonMWC for more updates!
# Date:  2023-02-27 15:30:45
# Likes:  24
# Comments:  0
# Shares:  0
# Sentiment:  0.9595
#
#
# Post:  How will we interact with the world in the next decade?
#
# The exciting emergence of #5G, #AI, VR, and AR technologies are revolutionizing the way people connect with the world. Learn more from the “Delivering theअधिक digital decade” session at #MWC23, featuring Ericsson’s President & CEO Börje Ekholm, alongside other great thought leaders and technology experts.
#
# 📍 Go to the Keynote Stage in Hall 4 on February 27, 12:00 CET and join the conversation!
#
# Follow #EricssonMWC for more updates.
# Date:  2023-02-27 14:30:38
# Likes:  80
# Comments:  1
# Shares:  0
# Sentiment:  0.8687
#
#
# Post:  Launch your #MWC23 week with #ImagineLive 🚀
#
# This session will give you a starting point for the exciting and busy days of innovation, new launches, and networking ahead. Join President & CEO, Börje Ekholm, CTOअधिक Erik Ekudden, Intel CEO Pat Gelsinger and many more of our experts, as they walk you through our demos, portfolio, and offerings live from Barcelona!
#
# ▶ Tune in on February 27, 9:00 AM CET on LinkedIn.
#
# #ImaginePossible #EricssonMWC
# Date:  2023-02-27 11:51:21
# Likes:  41
# Comments:  1
# Shares:  0
# Sentiment:  0.8655
#
#
# Post:  The race to #NetZero is now at full speed—can we keep up?
#
# Get an insight into whether the industry is meeting its sustainability targets with Ericsson’s Freddie Södergren and leading experts at #MWC23!
#
# ➡️ Be there live on February 27, 14:45 CET, at MWC Stage B, Hall 6 and follow #EricssonMWC for updates!
# Date:  2023-02-26 22:00:14
# Likes:  33
# Comments:  0
# Shares:  0
# Sentiment:  0.0
#
#
# Post:  The Open API marketplace is the place to be. Find out why at #MWC23!
#
# Listen to our CTO, Erik Ekudden, Savinay Berry, and other industry-leading experts as they discuss the opportunities empowered by API #अधिकinnovation and its potential to transform application development processes and revolutionize value creation.
#
# 📍 Be at MWC Stage A in Hall 6 on February 27, 13:15 CET and follow #EricssonMWC for updates!
# Date:  2023-02-26 20:30:39
# Likes:  72
# Comments:  0
# Shares:  0
# Sentiment:  0.7707
#
#
# Post:  How will we connect with the world in 10 years?
#
# Find out from the “Delivering the digital decade” session at #MWC23, featuring Ericsson’s President & CEO Börje Ekholm as one of the keynote speakers. Focusing onअधिक the advancements in #5G, #AI and other innovative technologies, the speakers of the panel will explore the future of connectivity.
#
# 👉 Find the Keynote Stage in Hall 4 on February 27, 12:00 CET and join the discussion!
#
# #EricssonMWC
# Date:  2023-02-26 18:30:27
# Likes:  142
# Comments:  1
# Shares:  9
# Sentiment:  0.6588
#
#
# Post:  #ImagineLive is coming to you live from #MWC23!
#
# Make sure to catch this session via Linkedin and kick-start this exciting week of innovation, groundbreaking launches, and networking!
#
# Featuring our President &अधिक CEO, Börje Ekholm, CTO Erik Ekudden, and many more of our industry-leading experts, we will give you a glimpse into our future and a walk-trough of our incredible demos and portfolio items.
#
# 🔴 Tune in on February 27, 9:00 AM CET!
#
# #ImaginePossible #EricssonMWC #Technology #Innovation
# Date:  2023-02-26 15:30:54
# Likes:  43
# Comments:  0
# Shares:  0
# Sentiment:  0.9027
#
#
# Post:  Meet our speakers at #MWC23, discussing the hottest topics in technology with industry leaders and trailblazing innovators
#
# Hear Ericsson’s President & CEO Börje Ekholm, and some of our leading experts, such asअधिक CTO Erik Ekudden, Sibel Tombaz, Ebru Kirac, and many others, taking a deep dive into:
#
# ✔️ #5G acceleration
# ✔️ open #mobile networks
# ✔️ #AI and other immersive technologies
#
# 👉 Follow #EricssonMWC for updates
# More info? 🔗 Visit us at https://www.ericsson.com/en/events/mwc?utm_medium=social_organic&utm_source=facebook&utm_campaign=gfmc_cspg-mwc23_20230227
# Date:  2023-02-22 21:30:41
# Likes:  352
# Comments:  2
# Shares:  0
# Sentiment:  0.0
#
#
# Post:  Kick off a week of excitement ⚡⚡⚡ with us at #MWC23 with our #ImagineLive session!
#
# Hear our President & CEO, Börje Ekholm, our CTO Erik Ekudden, and many more of our market-leading experts as they walk youअधिक through our demos and our vision for the future of connectivity.
#
# ➡ Listen and watch live on February 27, 9:00 AM CET on LinkedIn.
#
# #ImaginePossible #EricssonMWC
# Date:  2023-02-21 13:33:45
# Likes:  49
# Comments:  0
# Shares:  0
# Sentiment:  0.6696
#
#
# Post:  According to our 10 Hot Consumer Trends Report, what is the second most popular trend for the 2030s among urban early adopters?🔮
#
# 📶 Reliable,
# 🦾 Resilient
# 🔒 And secure internet connections.
#
# Learn more about theअधिक increasing consumer dependency on unbroken connections. Download the full report here ➡️ http://m.eric.sn/6mJa50MVCsW
#
# #ImaginePossible #ConsumerTrends
# Date:  2023-02-19 21:31:39
# Likes:  30
# Comments:  0
# Shares:  0
# Sentiment:  0.6697
#
#
# Post:  We’re exploring the future of technologies right now to help service providers take consumer experiences to the next level.
#
# If you’re curious to see how intelligent machines will cooperate and interact in theअधिक digital world over real-world connections, you’ll find us at 📍 MWC Barcelona in Barcelona, showcasing our groundbreaking extended reality, AI, security and sustainability advancements.
#
# See you at hall 2! 👋 Follow #EricssonMWC for updates. http://m.eric.sn/fuYZ50MUE50
#
# #ImaginePossible #MWC23 #Innovation #AI #Sustainability
#
# ERICSSON.COM
# Ericsson at Mobile World Congress Barcelona 2023
# Date:  2023-02-17 17:30:47
# Likes:  114
# Comments:  0
# Shares:  0
# Sentiment:  0.9381
#
#
# Post:  Zero-energy devices as small as a grain of rice could one day harvest ambient energy from the world around them, driving total transformation of industries including:
#
# 🏥 Healthcare
# 🌾 Farming & Agriculture
# 📦अधिक Warehousing
# 🏭 Manufacturing
# ⛏ Mining
# 🔮 And so many more!
#
# Imagine the possibilities of zero-energy devices for each in our new article ➡️ http://m.eric.sn/iU1i50MS58O
#
# #ZeroEnergy #NetZero #Sustainability
# Date:  2023-02-15 14:31:59
# Likes:  25
# Comments:  1
# Shares:  0
# Sentiment:  0.3382
#
#
# Post:  In a world of digital everything, we can create unlimited possibilities with limitless connectivity.
#
# At MWC Barcelona we’ll show you how.
#
# Are you ready to get started? 📍 See us in Hall 2!
#
# Follow #EricssonMWC for updates
# More info 🔗 http://m.eric.sn/vqNE50MQt1m
#
# #ImaginePossible #MWC23 #Innovation #Technology
# Date:  2023-02-13 17:31:13
# Likes:  47
# Comments:  1
# Shares:  0
# Sentiment:  0.7574
#
#
# Post:  🗣 Introducing brand new software and hardware solutions, enabling greater #5G capacity for indoor and outdoor deployments.
#
# 🌍 10+ new radios plus new software in our 5G RAN and Transport portfolios achieveअधिक more capacity with less energy-usage and carbon footprint for outdoor connectivity. Visit http://m.eric.sn/pfPb50MOXG0 for more
#
# 🏨 Not only that, we've expanded our industry-leading indoor 5G portfolio with new hardware and software, making it easier for service providers, enterprises and neutral hosts to deploy, scale, and monetize 5G. More info here: http://m.eric.sn/3fHW50MOXK0
#
# 🤝 Anything needed for indoor and outdoor 5G deployments, we have it covered.
#
# #EricssonMWC #MWC23 #energyefficiency #backhaul #technology #indoor #telecom
# Date:  2023-02-09 22:00:00
# Likes:  98
# Comments:  0
# Shares:  0
# Sentiment:  0.7184
#
#
# Post:  Ready to transform online trainings into immersive, hands-on experiences?
# We teamed up with Orange Polska to show how virtual reality can revolutionize learning.
#
# The opportunity presented itself when a 5Gअधिक Standalone deployment project started in Poland. With the help of the new platform, 5G network engineers used cutting-edge #VR technology to learn about the 5G core network architecture and its capabilities.
#
# Watch this video to get a glimpse into the future of virtual reality training ⬇️
#
# #5G #VR #Metaverse #Digital #Training #Technology
# Date:  2023-02-07 16:32:04
# Likes:  92
# Comments:  3
# Shares:  0
# Sentiment:  0.7906
#
#
# Post:  The global financial situation has stretched consumer budgets thin. In our 10 Hot Consumer Trends Report, readers will discover how consumers want future digital services to help control:
#
# 🍳 Food,
# ⚡️ Energy,
# 🚙अधिक And travel costs,
# 🌍 All in a world facing an unstable climate situation?
#
# Download the full report here ➡️ http://m.eric.sn/MzO950MEoKf
#
# #Digitalization #ClimateChange
# Date:  2023-01-30 19:16:49
# Likes:  23
# Comments:  0
# Shares:  0
# Sentiment:  0.3818
#
#
# Post:  How can technology improve access to quality education? 🤔
#
# From developing new teaching skills to creating more engaging classes, explore how Virtual Reality 🥽 training for teachers open up a world of excitingअधिक opportunities in the classroom.
#
# 👉 http://m.eric.sn/u9tn50MyBHs
#
# #EducationDay #DigitalInclusion #VirtualReality #ConnectToLearn
# Date:  2023-01-24 15:06:30
# Likes:  33
# Comments:  0
# Shares:  0
# Sentiment:  0.8553
#
#
# Post:  Our 10 Hot Consumer Trends Report is out now!
#
# Discover the 🔟 technology areas most relevant for consumers as we enter a world more affected by #ClimateChange, with topics including:
#
# 💶 Cost savings,
# ⚡️ Energy,
# ⛑ Safety,
# 🤳 And enjoyability of digital experiences!
#
# Access the full report here ➡️ http://m.eric.sn/IlJK50Mqm8Z
# Date:  2023-01-16 13:45:37
# Likes:  34
# Comments:  8
# Shares:  0
# Sentiment:  0.784
#
#
# Post:  🌐“Bridging the digital divide with connectivity and digital skills is key to economic growth and social inclusion.”
#
# Explore all 5️⃣ ways connectivity and digitalization can help build dynamic, sustainable andअधिक innovative economies that deliver inclusive growth in this new blog post from our CEO Börje Ekholm.
#
# Discover more 👉 http://m.eric.sn/tWO450Mqkgx
#
# #Sustainability #Connectivity #Digitalization #WEF23
# Date:  2023-01-13 21:12:10
# Likes:  74
# Comments:  1
# Shares:  0
# Sentiment:  0.9081
#
#
# Post:  How to start moving toward a more inclusive and sustainable future in the current global crises?🤔
#
# In a new blog post, Ericsson's Åsa Tamsons shares why impact investments 💡 have a key role to play in tacklingअधिक the world’s biggest challenges and creating a positive, lasting change.
#
# Explore more 👉 http://m.eric.sn/Slat50MpY2v
#
# #Innovation #Sustainability #WEF23
#
# ERICSSON.COM
# How can impact investors accelerate positive change
# Date:  2023-01-13 16:09:58
# Likes:  36
# Comments:  0
# Shares:  0
# Sentiment:  0.9423
#
#
# Post:  Happy New Year to all our customers! 🎉 You make every day meaningful for us, and we can’t wait to continue collaborating with you next year!
#
# Your trust and loyalty mean more to us with every passing year. Thank you for choosing us—here’s to making each year better than the last! 🥂
#
# #2023 #NewYear #TeamEricsson
# Date:  2023-01-01 13:33:30
# Likes:  113
# Comments:  5
# Shares:  0
# Sentiment:  0.9673
#
#
# Post:  What were your most memorable moments in 2022? 💭
#
# At #TeamEricsson, we’re so grateful to have had so many this year! ⤵️
#
# 🌱 Seeing the rebirth of mangrove trees in the Philippines and Malaysia supported byअधिक Ericsson’s ICT solutions. To capture this amazing journey of reforestation, we shared a short documentary film about our Connected Mangroves project in partnership with the BBC.
#
# 📍 Experiencing our first event, Imagine Possible Santa Clara, that brought together the XR, Metaverse, and enterprise ecosystem communities to connect, create, and innovate with 5G.
#
# 🎉 Celebrating Ericsson Pride with our excellent teams. Across multiple platforms and locations (online and offline), we came together and showed our commitment to diversity and inclusion at our company.
#
# We can’t wait to experience more great moments like these in 2023! 🤩
#
# #2023 #NewYear #TeamEricsson
# Date:  2022-12-31 13:31:42
# Likes:  70
# Comments:  1
# Shares:  0
# Sentiment:  0.9908
#
#
# Post:  What’s on your wish list this #holiday season? 🎁
#
# 💭 As we step into 2023, at #TeamEricsson, our wish for the world is a better and brighter tomorrow, filled with limitless possibilities through the power of connectivity.
#
# From our #TeamEricsson family to yours, we’re wishing you a peaceful #holiday season! 🤗
# Date:  2022-12-25 15:31:20
# Likes:  139
# Comments:  2
# Shares:  6
# Sentiment:  0.9761
#
#
# Post:  Are you experiencing gift-giving anxiety as the holiday period approaches? 🎁
#
# If so, we have good news for you. Digital transformation in the consumer space 🛍️ is about to revolutionize online shopping withअधिक extended reality (XR).
#
# 🥽 How about using try-before-you-buy filters, visiting never-ending virtual stores from the comfort of your home, or NFT fashion items? The possibilities are limitless.
#
# Explore the XR future of immersive shopping experiences in this blog post 🔽
# http://m.eric.sn/76bv50M96hv
#
# #ConsumerLab #ConsumerTrends #XR
#
# ERICSSON.COM
# Christmas shopping and XR: What’s changing?
# Date:  2022-12-22 23:31:37
# Likes:  28
# Comments:  0
# Shares:  0
# Sentiment:  0.8702
#
#
# Post:  📍 At Imagine Possible Santa Clara, we took a closer look at how digitalization transforms our world as we know it. Did you miss it? Don’t worry, you can watch back the videos now on demand! 👇
#
# Featuring leadingअधिक innovators, thought leaders, and tech front-runners such as Neville Ray from T-Mobile, Ann-Sofie Isaksson from IKEA, Bikash Koley from Google, and over 9️⃣0️⃣ other speakers from industry-leading companies, this exciting event brought together the brightest ✨ minds of the industry.
#
# ▶ Head over to our Imagine Possible Santa Clara page now to see the recordings: http://m.eric.sn/NcwM50M8gav
#
# #ImaginePossible #ImagineLive
# Date:  2022-12-20 19:45:19
# Likes:  29
# Comments:  0
# Shares:  1
# Sentiment:  0.829
#
#
# Post:  The #5G innovation platform brings immense opportunities to service providers, enterprises and developers. Are you ready to discover the opportunities it brings to the developing Communications Platform as aअधिक Service (CPaaS) market? 🤔
#
# Discover the #CPaaS market's potential to empower:
#
# 🔘 #Developers with a gearbox for new use cases,
# 🔘 #Enterprises with secure 5G network capabilities,
# 🔘 And service providers with monetized investments.
#
# It's all covered by our CTO, Erik Ekudden, and Vonage Head of Strategy Vinod Lala in this CTO Focus Session 👉 http://m.eric.sn/h0XJ50M5qiE
# Date:  2022-12-16 17:48:18
# Likes:  60
# Comments:  2
# Shares:  0
# Sentiment:  0.8934
#
#
# Post:  The journey to achieving the opportunities that come with a growing Communication Platform as a Service (CPaaS) market lies ahead.
#
# 🛣 Let our CTO, Erik Ekudden, and Vonage Head of Strategy Vinod Lala lead youअधिक to the destination through innovation in #5G and APIs! 📶
#
# Learn to build & adopt new use cases to monetize network investments in their new CTO Focus Session ➡️
#
# https://www.ericsson.com/en/about-us/new-world-of-possibilities/cto-focus-session#vonage/?utm_source=facebook&utm_medium=social_organic&utm_campaign=gfmc_global_bilp_cto-focus-session-vonage_20221209
#
# #CPaaS #Digitalization
# Date:  2022-12-09 12:45:38
# Likes:  56
# Comments:  4
# Shares:  0
# Sentiment:  0.6239
#
#
# Post:  ARound AR Founder & CEO Josh Beatty and Ericsson Consumer & IndustryLab Head of Research Agenda & Quality Michael Björn are exploring how #XR innovations can enable + advance our daily lives right now — Capture their insight at Imagine Live! 🎥🔴
#
# Join the immersive experience conversation
#
# #ImagineLive #EricssonChats
# Date:  2022-12-06 20:08:55
# Likes:  39
# Comments:  13
# Shares:  0
# Sentiment:  0.3595
#
#
# Post:  ARound AR Founder & CEO Josh Beatty and Ericsson Consumer & IndustryLab Head of Research Agenda & Quality Michael Björn are exploring how #XR innovations can enable + advance our daily lives right now — Capture their insight at Imagine Live! 🎥🔴
#
# Join the immersive experience conversation
#
# #ImagineLive #EricssonChats
# Date:  2022-12-06 19:37:44
# Likes:  25
# Comments:  1
# Shares:  0
# Sentiment:  0.3595
#
#
# Post:  Are you reading this from a smart device? 📱The video uses video compression technology, which our Inventor of the Year winners, the VISTA team, have contributed to!
#
# Time to meet the winners: http://m.eric.sn/2XLq50LPQ8l
#
# #IoY2022 #VideoCompression #5G
# Date:  2022-12-06 18:15:35
# Likes:  34
# Comments:  0
# Shares:  0
# Sentiment:  0.8478
#
#
# Post:  Digital + physical worlds are converging, unlocking countless 🆕 #XR applications for immersive experiences in our daily lives.🔮 Explore them with ARound AR Founder & CEO Josh Beatty and Ericsson Consumer &अधिक IndustryLab Head of Research Agenda & Quality Michael Björn at Imagine Possible!✨
#
# Join Josh and Michael on December 6th to discover the future of extended reality and explore how #5G #Connectivity play a critical role in enabling it.
#
# Register for the #FacebookLive event here 👉 http://m.eric.sn/hJVg50LTsfR
#
# #ImagineLive #EricssonChats
# Date:  2022-12-02 18:40:44
# Likes:  26
# Comments:  0
# Shares:  0
# Sentiment:  0.5983
#
#
# Post:  Meet Frank, one of our Inventors of the Year 2022! 👏 Frank talks us through his specialism in network restoration and how he achieved his career goals.
#
# Watch his full story: http://m.eric.sn/YOjr50LPPXU
#
# #IoY2022 #5G #Engineering #Networks #Technology
# Date:  2022-12-02 17:32:47
# Likes:  39
# Comments:  2
# Shares:  0
# Sentiment:  0.0
#
#
# Post:  We never feel insecure when we use secure + strong #5G!📶 Happy #ComputerSecurityDay! 🔒
#
# #DYK: 5G is up to 100 times faster than #4G. With faster #connectivity speeds, ultra-low latency, and greater bandwidth, 5G is a truly resilient system. Discover the layers of 5G security and how to best protect end-users ➡️
# Date:  2022-11-30 22:34:20
# Likes:  24
# Comments:  0
# Shares:  0
# Sentiment:  0.9774
#
#
# Post:  📰 This just in: 5G population coverage is projected to reach 8️⃣5️⃣% by the end of 2028. What does this mean for society and service providers?
#
# Stay up-to-date on the developments in the telecom industry withअधिक the newly released ⚡ Ericsson Mobility Report, bringing you the latest trends, projections, data, and industry-leading analysis.
#
# 📌 Read now: http://m.eric.sn/2cQ750LQKVv
#
# #MobilityReport #5G #Networks
# Date:  2022-11-30 17:31:36
# Likes:  62
# Comments:  0
# Shares:  0
# Sentiment:  0.0258
#
#
# Post:  We're on a mission to lower emissions, and it can't be done alone 🌍 — Join Ericsson's Climate Action Manager Emelie Öhlander and GSMA's Head of Climate Action, Steven Moore, right now at Imagine Live! 🎥🔴
#
# Join the #ClimateAction conversation here on #FacebookLive
#
# #ImagineLive #EricssonChats
# Date:  2022-11-29 19:26:24
# Likes:  34
# Comments:  16
# Shares:  0
# Sentiment:  0.4993
#
#
# Post:  What sparked your curiosity as a child? 👀 For Siva, it was the magic of technology.
#
# Learn about his journey to becoming a 2022 Inventor of the Year winner 🎉 http://m.eric.sn/JcRs50LPPyO
#
# #IoY2022 #5G #Technology #Innventing
# Date:  2022-11-29 17:30:47
# Likes:  24
# Comments:  0
# Shares:  0
# Sentiment:  0.7579
#
#
# Post:  मंगल, 6 दिसं 2022
# Imagine Live: Unlocking XR in our daily lives
# Date:  2022-11-25 20:45:26
# Likes:  25
# Comments:  0
# Shares:  0
# Sentiment:  0.0
#
#
# Post:  🛣 Our CTO, Erik Ekudden, and President & CEO of Scania and Traton Group Christian Levin, have mapped the global journey to sustainable transportation through #5G #Connectivity:
#
# ➡️ Take a right toward connectedअधिक vehicle data,
# ➡️ Which leads to fuel-efficient engine development,
# ➡️ Then head straight on toward significant economic + climate improvement!
#
# Learn more about 5G's role in achieving climate goals in this CTO Focus Session ➡️ http://m.eric.sn/xcrj50LMYgI
#
# #Sustainability #Digitalization
# Date:  2022-11-24 23:31:19
# Likes:  37
# Comments:  0
# Shares:  0
# Sentiment:  0.7177
#
#
# Post:  There are countless, concrete actions the Telco industry can take to address climate crisis across the value chain by 2️⃣0️⃣4️⃣0️⃣. Ready to unlock them and achieve your #Sustainability goals? 🌍
#
# Join us onअधिक November 29, 15:00 CET for Imagine Live, where Ericsson and GSMA experts will unveil insights into what is needed to achieve Net Zero emissions globally. 🤝
#
# Register to join the #FacebookLive conversation here 👉 http://m.eric.sn/8VK250LLX88
#
# #ImagineLive #EricssonChats
# Date:  2022-11-23 18:39:53
# Likes:  28
# Comments:  2
# Shares:  0
# Sentiment:  0.4939
#
#
# Post:  📣 Breaking news from the world of 6G! At Ericsson, we're excited to announce a new multi-million-pound investment in a UK 6G research program that will boost network innovation, drive the development of globalअधिक standards and lead the way to a more connected, advanced and sustainable society.
#
# Ericsson’s dedicated research team and supporting PhD students will focus on breakthrough technologies in areas such as network resilience and security, artificial intelligence, cognitive networks and energy efficiency – all considered to be key building blocks of the world’s future digital infrastructure.
#
# The investment in 6G research capabilities continues Ericsson’s long history at the heart of telecommunications in the UK and ensures the country remains a global leader in the technologies and industries of the future.
#
# http://m.eric.sn/MXyC50LKxtC
#
# #6G #Ericsson #Innovation #Technology
# Date:  2022-11-22 15:35:46
# Likes:  71
# Comments:  2
# Shares:  0
# Sentiment:  0.9821
#
#
# Post:  What does the future hold for the telecom industry? Get a glimpse of what’s to come in latest Mobility Report!
#
# Join our experts LIVE 🔴 on November 30 to discuss ground-breaking data, fascinating insights, and forecasts from the report.
#
# Register here 📌 http://m.eric.sn/nlov50LJoCR
#
# #MobilityReport #Technology #Webinar
# Date:  2022-11-21 16:04:58
# Likes:  40
# Comments:  0
# Shares:  0
# Sentiment:  0.7177
#
#
# Post:  The 2022 Ericsson Inventor of the Year winners 🥇 have been announced!
#
# Congratulations to the winners on their achievements and contributions to our patent portfolio 🙌
#
# Watch the video to meet the inventors who are shaping the future of #MobileTechnology
#
# #IoY2022 #Technology #5G #Innovators
#
# ERICSSON.COM
# Inventor of the Year award
# Date:  2022-11-14 15:45:12
# Likes:  105
# Comments:  4
# Shares:  0
# Sentiment:  0.9516
#
#
# Post:  Curious to see how can we restore nature with the power of ICT solutions? 👀
# Then check out the story of our Connected Mangroves project!
#
# We took our tech to the Philippines and Malaysia to help foster andअधिक maintain mangrove forests 🌳
#
# 🎯 At Ericsson, our mission is to showcase how connectivity can combat climate change and inspire positive change around the world with the use of technology. Projects like these demonstrate that our solutions can effectively help create a more sustainable world.
#
# ▶ Check out the video and find out more about how ICT can be used for climate action http://m.eric.sn/Vzc050LA4Fa
#
# #ConnectedMangroves #AgeOfChange #Innovation #COP27
#
# www.ageofchangeseries.co.uk
# Date:  2022-11-10 21:34:42
# Likes:  35
# Comments:  1
# Shares:  0
# Sentiment:  0.9804
#
#
# Post:  This year, at #COP27, we want to see all kinds of solutions—from nature-based solutions to energy solutions.
#
# Learn more from climate leaders, such as Johan Rockström, industry leaders like Steven Moore, andअधिक our own Ericsson experts, Mats Pellbäck Scharp and Emelie Öhlander at COP27, in partnership with Wedonthavetime.org United Nations Development Programme - UNDP and the Exponential Roadmap Initiative where they'll discuss:
#
# 👉 Green transformation of business and society
# 👉 ICT solutions that help solve the climate crisis
#
# Save the date 🌍 November 10
#
# 🔗🔽 Register now
#
# #COP27 #Sustainability #ClimateChange #ClimateAction #ICT #NetZero
#
# WEDONTHAVETIME.ORG
# COP27 Climate Hub – Nov 07, 2022–Nov 17, 2022
# Date:  2022-11-09 18:30:20
# Likes:  15
# Comments:  0
# Shares:  0
# Sentiment:  0.9081
#
#
# Post:  In an increasingly digital world, the lack of access to connectivity poses a risk for the digital divide to grow wider. So, what can be done to prevent this? 🤔
#
# 📍 In advance of the B20 Summit in Indonesia laterअधिक this month, and as co-chair of the Digitalization Taskforce, our CEO Börje Ekholm shares a letter to the G20 on the importance of digitalization and the need for universal connectivity – especially for micro, small, and medium businesses.
#
# Its message is clear: creating a future that is full of opportunities requires networks to be put in place at scale, fast and affordably. While providing people with the access, devices, and skills needed to thrive in a digital world.
#
# ➡ Read the full letter here: http://m.eric.sn/7keV50Lxn6V
#
# #B20 #G20 #Digitalization #B20Indonesia"
#
# ERICSSON.COM
# G20: it's time to extend digital to small businesses
# Date:  2022-11-08 16:57:00
# Likes:  58
# Comments:  0
# Shares:  0
# Sentiment:  0.8176
#
#
# Post:  Can #ICT help support climate action?
#
# The answer is yes. Here's how our technology can help the 3️⃣ pillars of #ClimateAction
#
# 🏭 Mitigation: reducing the emission of greenhouse gases
# 🌎 Adaptation: monitoringअधिक and alert systems help manage disasters
# 💪 Resilience: dealing with the effects of climate change
#
# This #COP27, we look forward to valuable discussions on concrete #Sustainability solutions and partnerships that support real, positive change around the world.
#
# 👉 Find out more in this blog post: http://m.eric.sn/fKVo50Lw7OT
#
# ERICSSON.COM
# COP 27: ICT and climate mitigation, adaption and resilience
# Date:  2022-11-07 21:30:38
# Likes:  16
# Comments:  0
# Shares:  0
# Sentiment:  0.9648
#
#
# Post:  Taking action to achieve global Net Zero emissions is more important than ever. How can the telco industry join the effort to tackle this #Sustainability challenge?🤔
#
# Ericsson's Climate Action Program Manager,अधिक Emelie Öhlander, and GSMA's Head of Climate Action, Steven Moore, have answers at Imagine Live!✨ Join them on November 29, 15:00 CET to unlock their sustainability leadership & research insights.🌍
#
# Join us on #FacebookLive
#
# #ImagineLive #EricssonChats #ClimateAction #Digitalization
#
# मंगल, 29 नवं 2022
# Imagine Live: The road from COP27 to Net Zero
# Date:  2022-11-07 20:45:09
# Likes:  21
# Comments:  0
# Shares:  0
# Sentiment:  0.862
#
#
# Post:  मंगल, 29 नवं 2022
# Imagine Live: The road from COP27 to Net Zero
# Date:  2022-11-07 20:43:07
# Likes:  6
# Comments:  0
# Shares:  0
# Sentiment:  0.0
#
#
# Post:  It's no trick — Delivering on our #Sustainability goals and creating real #ClimateAction is such a treat!
#
# It's our responsibility to make the world a little less spooky through creating innovative technology and positive impact. Happy #Halloween from Ericsson! 🎃
# Date:  2022-10-31 20:32:31
# Likes:  19
# Comments:  0
# Shares:  0
# Sentiment:  0.9499
#
#
# Post:  We're taking innovation in sustainable transportation full throttle — Our CTO, Erik Ekudden, and President & CEO of Scania and Traton Group Christian Levin, share how! 🚙✨
#
# Tune-in to their CTO focus session forअधिक an insightful discussion on #Digitalization's role in reaching the transportation industry's #Sustainability goals. Discover the future of an electrified transport system here ➡️ http://m.eric.sn/W7uL50LplzZ
#
# #ImaginePossible #CTO #SustainableTransportation
# Date:  2022-10-31 15:28:16
# Likes:  38
# Comments:  0
# Shares:  0
# Sentiment:  0.8016
#
#
# Post:  This month, we are celebrating the 2-year anniversary of our partnership with UNICEF & ITU and work to help Giga map connectivity in every school.🌐
#
# Hear more from Giga's Sophia Farrar: http://m.eric.sn/kRIR50LlYWG
#
# #DigitalInclusion
# Date:  2022-10-28 16:31:52
# Likes:  41
# Comments:  1
# Shares:  0
# Sentiment:  0.7506
#
#
# Post:  Mapping school connectivity creates real change. That’s why we’ve partnered with UNICEF in support of ITU & UNICEF's Giga initiative on closing schools’ connectivity gap.
#
# Over the first two years of ourअधिक partnership, we've been working to understand the magnitude of the problem. Here are our 3️⃣ key takeaways:
#
# 🤝 Strong public-private partnerships are essential in closing the digital divide
# 👨‍💻 Technical expertise and innovation are key to mapping connectivity gaps
# 🌐 Schools need meaningful connectivity
#
# Dive deeper in this blog post http://m.eric.sn/FoYq50Lmr2h
#
# #ConnectingSchools #DigitalInclusion #Connectivity
# Date:  2022-10-27 14:30:19
# Likes:  39
# Comments:  0
# Shares:  0
# Sentiment:  0.8519
#
#
# Post:  Would you like to learn about new digital experiences and how they can transform our world? Sign up for the highlights of our Imagine Possible live show!
#
# Over the two days we were in Santa Clara, we had amazingअधिक speakers from industry-leading companies sharing their thoughts on how connectivity will revolutionize how humans engage, learn, and experience our world.
#
# ▶ Register now to watch the replays: http://m.eric.sn/PzH550LjbAI
#
# #ImaginePossible #ImagineLive
# Date:  2022-10-26 17:31:35
# Likes:  28
# Comments:  0
# Shares:  0
# Sentiment:  0.8553
#
#
# Post:  Have you heard the news?🤔 We've shipped 9️⃣ million #5G ready radios worldwide! That's 9️⃣ million solutions empowering partners & customers to unlock innovations in:
#
# 🎮 Cloud gaming
# 🕶️ Virtual realities
# 🚍अधिक Autonomous vehicles
# 🔮 And more!
#
# As the 5G innovation platform continues to grow, these 9️⃣ million units will only accelerate it. What makes 5G different? Check this out ➡️ http://m.eric.sn/k4l150LkbW6
# Date:  2022-10-25 18:54:01
# Likes:  43
# Comments:  2
# Shares:  0
# Sentiment:  0.7746
#
#
# Post:  🎉 Today, we celebrate International #PronounsDay to champion the values we believe in.
#
# Creating spaces where people can feel free to be themselves is part of our Ericsson culture. An integral part of thisअधिक culture is recognizing people for who they are and continuously encouraging and empowering them to express their true selves in the workplace and beyond 🚀
#
# We know it takes a lot of courage to be our true selves. And the least we can do for ourselves and others is to celebrate that courage with our words and actions.
#
# 🔗 Learn more about how we do it and join the celebration: http://m.eric.sn/p7Eb50Lf9vq
#
# ERICSSON.COM
# International Pronouns Day: Why it matters to Ericsson?
# Date:  2022-10-19 17:05:59
# Likes:  20
# Comments:  1
# Shares:  0
# Sentiment:  0.9898
#
#
# Post:  💡 It’s time to think differently about how we plan, deploy, and operate networks.
#
# 🔋 While the energy conscious, future-proof portfolio of 5G is evident, it’s simply not enough on its own to dramaticallyअधिक reduce energy consumption for entire mobile networks. We must utilize the latest technology advances to enable energy-saving functionalities to the fullest and consider our energy sources.
#
# 📈 Currently, the annual global energy cost for running mobile networks is about 25 billion US dollars and if 5G is deployed the same way as previous generations, energy consumption will increase continuously.
#
# It’s time to make real changes for a more sustainable future. At Ericsson, we have both the experience and foresight to plan, deploy, and operate networks that prioritize performance and generate energy and cost savings.
#
# 👉 Read the new “On the road to breaking the energy curve” report available now: http://m.eric.sn/oRcN50LcTVM
#
# #EnergyCurve #Sustainability #5G
# Date:  2022-10-18 15:30:52
# Likes:  33
# Comments:  1
# Shares:  0
# Sentiment:  0.9186
#
#
# ...
#
# 💪 Just as our colleague, Sorour Falahati, we believe there are many girls andअधिक young women in the world who were born to be problem-solvers. Their passion and valuable knowledge are exactly what we, as key players of the ICT industry, need to create more innovations, and ultimately, a more equal world.
#
# 🤝 At #Ericsson, we strive to create a culture that enables everyone to realize their potential.
#
# #ImaginePossible #GirlsInICT
# Date:  2022-04-26 16:09:58
# Likes:  110
# Comments:  6
# Shares:  0
# Sentiment:  0.9674
#
#
# Post:  Join us live to discuss the opportunities of hybrid learning and the technology required to make it happen.
# Date:  2022-04-25 19:27:19
# Likes:  87
# Comments:  36
# Shares:  0
# Sentiment:  0.5859
#
#
# Post:  We are partnering with #Vodafone Idea Foundation to set up #Robotic 🤖 Labs across #India that will enable:
#
# ☑️ empowerment of students with Digital Skills
# ☑️ improving education across #STEM
# ☑️ provide learningअधिक experiences to children from underserved communities
#
# Explore 👇 how we are jointly empowering underserved students with digital learning skills through this initiative
#
# ERICSSON.COM
# Vodafone Idea to Set up Robotic Labs in schools
# Date:  2022-04-23 19:30:41
# Likes:  191
# Comments:  0
# Shares:  0
# Sentiment:  0.4215
#
#
# Post:  Let's talk 5G, #HybridLearning, the future of #education and new opportunities of the #Metaverse!
#
# Register to join us live! http://m.eric.sn/O6zk50IOtG3
# Date:  2022-04-21 15:47:35
# Likes:  584
# Comments:  2
# Shares:  0
# Sentiment:  0.658
#
#
# Post:  How do we work on creating a sustainable, positive impact while reducing carbon emissions by up to 15% by 2030 around the 🌎?
#
# 👉 Join our speakers, Fredrik Jejdling and Mats Pellbäck Scharp, at the 5️⃣अधिक Exponential Climate Action Summit by @WeDontHaveTime and find out!
#
# 🔗 Register now http://m.eric.sn/RQJB50INFIB and spend this #EarthDay discovering effective #ClimateAction in the #RaceToZero
# Date:  2022-04-21 13:30:29
# Likes:  54
# Comments:  0
# Shares:  3
# Sentiment:  0.8858
#
#
# Post:  Singapore is a global intersection for industries driving digital transformation. As the VP of 5G Enterprise & Cloud at Singtel, Dennis Wong is a technology expert with a spirit of innovation.
#
# With aअधिक future-focus mindset Singtel seeks to empower how the next generation thinks about global enterprise, and Dennis believes technology to be the lead enabler.
#
# #ImaginePossible #LimitlessConnectivity #Enterprise
# Date:  2022-04-20 19:31:24
# Likes:  116
# Comments:  0
# Shares:  0
# Sentiment:  0.5106
#
#
# Post:  Focus on the #network decisions where humans can contribute the most value – let the 🆕 Ericsson Performance Optimizers software handle the rest 🦾
#
# Using #AI native agnostic foundation and machine learning,अधिक Performance Optimizers can intelligently automate millions of complex tasks + processes while proactively boosting network performance 📶
#
# Discover the automated future-proof solutions and the technology behind them here ⤵️
# http://m.eric.sn/73NW50IJUYX
#
# #MachineLearning
#
# ERICSSON.COM
# Cognitive technology and software in networks
# Date:  2022-04-19 17:31:07
# Likes:  94
# Comments:  0
# Shares:  0
# Sentiment:  0.9324
#
#
# Post:  How can service providers build future-proof networks?🤔 By utilizing machine learning + machine reasoning — both are a critical part of building the future of:
#
# 📶 Autonomous networks,
# 🦾 Trustworthy #AI
# 🤳 And platforms for diverse customer expectations + use cases.
#
# Learn more in our blog ⤵️
# http://m.eric.sn/i2jV50IHZGE
#
# #ML #MR
# Date:  2022-04-13 20:31:01
# Likes:  72
# Comments:  1
# Shares:  7
# Sentiment:  0.3182
#
#
# Post:  #IoT is such a game-changer for all industries + enterprises. Not because of what it is, but because of what it has the potential to be. Happy #IoTDay.📶✨
#
# In utilizing IoT #Connectivity, businesses can:
#
# 📈 Makeअधिक operations more efficient,
# 💵 Unlock new revenue streams,
# 🤳 Increase customer engagement
# 📊 And unlock data-driven insights.
#
# Check out some of our top case studies below covering how IoT empowers enterprises to #ImaginePossible ⤵️ http://m.eric.sn/lQmC50IFHWk
#
# #Digitalization #DigitalTransformation #IoT
#
# ERICSSON.COM
# The Internet of Things (IoT) technology
# Date:  2022-04-09 21:09:03
# Likes:  137
# Comments:  1
# Shares:  0
# Sentiment:  0.9694
#
#
# Post:  Sports and players are entering the home itself🏠 — #5G will make it possible 📶
#
# Through the introduction of immersive 5G technologies like #AR + #VR into sporting events, every seat in the stands, or at home,अधिक can become the best seat in the stadium, guaranteed 🏟
#
# Learn exactly how 5G will improve how we watch games and their players in our blog ⤵️ http://m.eric.sn/5x7650Iy8vR
#
# ERICSSON.COM
# Future of sports: 5G and the sports experience
# Date:  2022-04-06 20:31:41
# Likes:  81
# Comments:  0
# Shares:  0
# Sentiment:  0.8625
#
#
# Post:  How to win big in the #gaming industry? 🤔
#
# 👉 Enable agile, automated business support systems that provide the flexibility and scalability to support high-performance mobile gaming.
#
# 💰 Tap into the emergingअधिक market for new 5G #mobile gaming services, which are estimated to be worth USD 138 billion by 2025.
#
# 🎮 Read our blog post about how #5G #Networks are winning over gaming enterprise customers.
#
# ERICSSON.COM
# Game on! How 5G is winning over gaming enterprise customers
# Date:  2022-04-04 19:31:30
# Likes:  53
# Comments:  0
# Shares:  0
# Sentiment:  0.9617
#
#
# Post:  Connected #cars are quickly becoming the standard and consumers expect more from the #digital experience than before. Automakers are evolving from manufacturers to #tech companies.
# With this, over-the-air (OTA)अधिक updates are becoming a more powerful tool to keep up with customer expectations.
#
# Here are 4️⃣ advantages of OTA updates for automakers: http://m.eric.sn/O7FC50ItLV5
#
# #Automotive
# Date:  2022-04-01 21:00:14
# Likes:  58
# Comments:  0
# Shares:  3
# Sentiment:  0.6801
#
#
# Post:  Hamburg's first private 5G standalone campus network is up and running!
#
# Commissioned by Dataport to support their 5G test lab, we've set up this pioneering network in partnership with Telefónica. Our technologyअधिक will empower Dataport to drive the digitalization of the public sector.
#
# With the advancement of smart cities, there is an increasing need for fast, reliable technology that can transfer and process large volumes of data increases. Using our scalable 5G campus network, Dataport's lab will enable enterprises and public institutions to test and optimize new 5G applications in real-world conditions. The result will be cutting-edge innovations that can be implemented in the public sector.
#
# This is what the future of smart cities looks like. This is the power of 5G.
#
# http://m.eric.sn/K0t150IxUpW
#
# #5Gnetwork #Innovation #O2Telefonica #Dataport
# Date:  2022-04-01 13:30:42
# Likes:  64
# Comments:  1
# Shares:  0
# Sentiment:  0.9402
#
#
# Post:  In a society where #connections are constantly increasing, how can we simplify networks so that they’re able to handle increasing amounts of data while also enabling a digital-first society?
#
# #AI may be theअधिक answer.
#
# 📌 Discover how AI could help shape the future of our society in this blog: http://m.eric.sn/vC9w50IvsVZ
#
# #Digitalization
# Date:  2022-03-31 19:34:25
# Likes:  58
# Comments:  1
# Shares:  0
# Sentiment:  0.4019
#
#
# Post:  Partnering with Airtel India we are powering a #5G remote drone inventory management solution in India 🇮🇳.
#
# Discover how it is enabling:
#
# ▪️ new possibilities with #drones
# ▪️ reducing manual intervention
# ▪️ smarter inventory management
#
# 📌 http://m.eric.sn/sgzs50IuToV
#
# #ImaginePossible #Industry40 #5GUseCase
# Date:  2022-03-29 18:01:56
# Likes:  94
# Comments:  3
# Shares:  0
# Sentiment:  0.6486
#
#
# Post:  Incredibly enough, 5G augmented reality is enabling 🇬🇧 Londoners to enter the world of the jungle without having to leave the city.
#
# What’s next?
#
# 👉 With good collaboration and the right technical setup, theअधिक sky’s the limit!
# 🦾 EE recent venture shows the world just what is possible with 5G augmented reality.
# 😎 The future of 5G is bright with an emphasis on proving the AR capabilities of 5G standalone.
#
# Explore 🌏 The Green Planet AR Experience: http://m.eric.sn/PF2P50ItK8S
#
# #ImaginePossible #5GAugmentedReality #Innovation
#
# ERICSSON.COM
# EE brings augmented reality to consumers with 5G
# Date:  2022-03-28 20:30:39
# Likes:  87
# Comments:  2
# Shares:  0
# Sentiment:  0.8966
#
#
# Post:  Our new energy-efficient Radio Access Network solutions are here!📡 Do you know the recipe for a successful #5G network? 👨‍🍳
#
# 🔌 Consistent user experience
# 🌎 Sustainable traffic growth
# 🔋 Nationwide 5G highअधिक performance
# and much more!
#
# The Result — 10 times more capacity 📶 zero added footprint👣and more energy efficient⚡️!
#
# Discover more ⤵️
#
# #ImaginePossible #Networks
#
# ERICSSON.COM
# Smart, slim and sustainable 5G networks
# Date:  2022-03-28 10:30:19
# Likes:  98
# Comments:  0
# Shares:  0
# Sentiment:  0.9446
#
#
# Post:  Introducing — Ericsson Dynamic End-user Boost, ready to put optimized #connectivity in your customers’ hands.
#
# The connectivity boost app for smartphones empowers business users, consumers, and enterprises withअधिक the ability to:
#
# 🔘 Connect and communicate with confidence,
# 🔘 Secure, fast download and upload speeds on the move,
# 🔘 Safeguard against unpredictable conditions with event prompted boosting,
# 🔘 All at the touch of a singular boost button.
#
# Start unlocking #5G monetization opportunities and boost customer satisfaction with our new application now: http://m.eric.sn/uIVA50IqkiH
#
# #Networks #4G #Digitalization
#
# ERICSSON.COM
# Dynamic End-user Boost: Optimize connectivity
# Date:  2022-03-25 15:30:39
# Likes:  67
# Comments:  0
# Shares:  0
# Sentiment:  0.9911
#
#
# Post:  As a sustainability pioneer in the private sector, our commitment to #ClimateAction is unwavering 🌎
#
# We've set an ambition to be Net Zero across the value chain by 2040, working with customers and suppliers toअधिक make it happen.
#
# Read our 2021 Sustainability and Corporate Responsibility report for a deeper dive into our achievements and goals for a sustainable future.
#
# #ImaginePossible #Sustainability #GreenTech
#
# ERICSSON.COM
# Sustainability & Corporate Responsibility Report
# Date:  2022-03-24 15:30:09
# Likes:  77
# Comments:  0
# Shares:  0
# Sentiment:  0.6124
#
#
# Post:  In partnership with Indian Institute of Technology Kanpur Airtel India and the Rajasthan Pollution Control Board, our #IoT solutions are enabling:
#
# ▪️ Air pollution monitoring in real-time
# ▪️ And policy interventions to reduce it 👍
#
# Explore how 👇⛅ http://m.eric.sn/cqxI50Iqfkn
# Date:  2022-03-23 21:30:53
# Likes:  61
# Comments:  0
# Shares:  0
# Sentiment:  0.1779
#
#
# Post:  💧 On this #WorldWaterDay, explore how groundbreaking possibilities like sensors, vertical farming and connected waters can make a difference.
#
# All on the latest 🔽 Technology & #Water episodes 🔽
#
# Technology &अधिक Water ☔ Rain
# Floods and heavy rainfall cost enormous sums of money every year. But there is already technology in our cell towers that we can use to get a better sense of where it rains and how much.
#
# Technology & Water 🌾 Vertical farming
# Despite huge advances, our food production is still inefficient in many ways. But this is about to change thanks to sensors and vertical farms.
#
# Technology & Water 🌀 The cycle
# Clean water is vital for both humans and nature. In this episode of Technology &, we visit the first facility in Sweden that uses new technology to remove drug residues from wastewater.
#
# Technology & Water 💧 Connected water
# To reduce the number of plastic bottles being transported around the world, this Swedish company has developed a much more sustainable system: a micro-factory that produces clean water locally.
#
# Watch them here: http://m.eric.sn/KSuH50Ipgx0
#
# #ImaginePossible
# Date:  2022-03-22 20:00:37
# Likes:  56
# Comments:  0
# Shares:  0
# Sentiment:  0.9542
#
#
# Post:  Together with Vodafone UK we have successfully completed the first UK test of 5G standalone (SA) end-to-end network slicing. As part of a joint lab demonstration, utilising Ericsson's 5G Standaloneअधिक containerized core architecture and 5G RAN slicing, we were able to create on-demand connectivity, with low latency and high bandwidth, in next to no time.
#
# With the success of this trial, the door is open for businesses and enterprises to benefit from a number of use cases. From increased effectiveness and efficiency to powering VR and AR technologies, 5G network slice will be at the forefront of delivering innovation, complete with faster time to market, as well as increased automation and customised connectivity. Another step toward the future of 5G.
#
# Read the full story:
# http://m.eric.sn/wW6x50IkRJ4
#
# #5G #Network #5GTrial #Vodafone
# Date:  2022-03-17 21:32:01
# Likes:  247
# Comments:  0
# Shares:  0
# Sentiment:  0.9571
#
#
# Post:  Imagine your network performing far more complex functions than ever before, intuitively and autonomously. Enabled by AI a network can become cognitive and can learn to improve itself.
#
# Discover the technologyअधिक trends shaping our future and how together we can make it Possible http://m.eric.sn/Vvzz50IkWtk
#
# #ImaginePossible #AI #Future
# Date:  2022-03-17 15:30:59
# Likes:  210
# Comments:  5
# Shares:  0
# Sentiment:  0.4404
# ---------------------------------------------------------------------------
# LoginRequired                             Traceback (most recent call last)
# Input In [7], in <cell line: 2>()
#       4 writer.writeheader()
#       6 # Loop over the posts on the page within the date range
# ----> 7 for post in get_posts(page_name, pages=50, extra_info=True, timeout=30):
#       8     if post["time"] < since_date or post["time"] > until_date:
#       9         continue
#
# File ~\Python310\lib\site-packages\facebook_scraper\facebook_scraper.py:1117, in FacebookScraper._generic_get_posts(self, extract_post_fn, iter_pages_fn, page_limit, options, remove_source, latest_date, max_past_limit, **kwargs)
#    1115 logger.debug("Extracting posts from page %s", i)
#    1116 for post_element in page:
# -> 1117     post = extract_post_fn(post_element, options=options, request_fn=self.get)
#    1118     if remove_source:
#    1119         post.pop('source', None)
#
# File ~\Python310\lib\site-packages\facebook_scraper\extractors.py:33, in extract_post(raw_post, options, request_fn, full_post_html)
#      30 def extract_post(
#      31     raw_post: RawPost, options: Options, request_fn: RequestFunction, full_post_html=None
#      32 ) -> Post:
# ---> 33     return PostExtractor(raw_post, options, request_fn, full_post_html).extract_post()
#
# File ~\Python310\lib\site-packages\facebook_scraper\extractors.py:205, in PostExtractor.extract_post(self)
#     202         log_warning("Exception while running %s: %r", method.__name__, ex)
#     204 has_more = self.more_url_regex.search(self.element.html)
# --> 205 if has_more and self.full_post_html:
#     206     post['source'] = self.full_post_html.find('.story_body_container', first=True)
#     208 if self.options.get('reactions') or self.options.get('reactors'):
#
# File ~\Python310\lib\site-packages\facebook_scraper\extractors.py:1351, in PostExtractor.full_post_html(self)
#    1349 logger.debug(f"Fetching {url}")
#    1350 try:
# -> 1351     response = self.request(url)
#    1352 except exceptions.NotFound as e:
#    1353     url = self.post.get('post_url').replace(FB_BASE_URL, FB_MOBILE_BASE_URL)
#
# File ~\Python310\lib\site-packages\facebook_scraper\facebook_scraper.py:942, in FacebookScraper.get(self, url, **kwargs)
#     936             raise exceptions.AccountDisabled("Your Account Has Been Locked")
#     937         elif (
#     938             title.text == "Log in to Facebook | Facebook"
#     939             or response.url.startswith(utils.urljoin(FB_MOBILE_BASE_URL, "login"))
#     940             or response.url.startswith(utils.urljoin(FB_W3_BASE_URL, "login"))
#     941         ):
# --> 942             raise exceptions.LoginRequired(
#     943                 "A login (cookies) is required to see this page"
#     944             )
#     945     return response
#     946 except RequestException as ex:
#
# LoginRequired: A login (cookies) is required to see this page

# %%
# Print a message when the data has been scraped and saved
print("Data has been scraped and saved to", csv_file)
# Out:
# Data has been scraped and saved to ericsson_facebook.csv
